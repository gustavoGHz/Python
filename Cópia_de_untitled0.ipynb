# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoGHz/Python/blob/main/C%C3%B3pia_de_untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 1 💯 ✅ ⏰

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ano = "IX"
print (ano, " competição de programação dá Start")

# %% [markdown]
# #Aula 2 🥑 🫀 👾

# %%
livro_ficcao = 8
  print(f"Ótimo, {nome},vamos falar sobre Python. \n Python é uma linguagem de programação usada para criar sites, jogos, aplicativos e muito mais, conhecida por ser simples e fácil de aprender. ")
elif resposta == "javascript":7Sx8kudTudjU9naX3vy4Ow
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_ana + pontos_rodrigo
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais do Ana são {pontos_ana}")
print(f"Os pontos totais de Ana e Rodrigo são {pontos_totais}")
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# # **Aula** **3** 🍙 🌭 🇬

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo

# %% [markdown]
# # **Aula** **4**  🖨 🚜 🎉

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} // {contador} = {numero // contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
print("olá, sou seu assistente virtual")
nome = input ("digite seu nome: ")
print(f"olá{nome}, em que posso ajudar?")
resposta = input("Você deseja falar sobre Python, javacript ou matemática: ").lower()
if resposta =="python":
  print(f"Ótimo, {nome},vamos falar sobre Python. \n Python é uma linguagem de programação usada para criar sites, jogos, aplicativos e muito mais, conhecida por ser simples e fácil de aprender. ")
elif resposta == "javascript":
  print(f"ótimo,{nome},vamos falar sobre Javascript. \n JavaScript é uma linguagem de programação usada principalmente para criar interatividade e dinamismo em páginas da web.")
elif resposta == "javascript":
  print(f"Otimo, {nome}, vamos falar sobre matemática. \n Matemática é a ciência que estuda números, formas, medidas e padrões para entender e representar o mundo ao nosso redor.")
else:
    print(f" Que pena, {nome}, não sei falar desse assunto")

# %% [markdown]
# # Aula 5 🍰 🦍 🧉

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} // {contador} import random
dica = [
    "Acredite em você — tudo começa com a sua própria confiança 🌟",
    "Pequenos passos também te levam longe; o importante é não parar 👣",
    "Erros fazem parte do aprendizado — cada falha é uma chance de crescer 📘",
    "Mantenha o foco no que realmente importa e não se distraia com comparações 🎯",
    "Celebre suas conquistas, mesmo as pequenas 🏆",
    "Seja constante, não perfeito 🔁",
    "Cuide da sua mente e do seu corpo — equilíbrio é essencial 🧘‍♂️",
]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n").lower()

  if pedido == "dica":
    dica = random.choice(dica) # escolhe uma dica aleatória sair
    print(f"dica: {dica} \n")
  elif pedido == "sair":
    print("até a próxima! \n")
    break
  else:
    print("omando inválido. tente novmente. \n")
    break= {numero // contador}")
numero = int(input("Digite um número para ver sua tabuada: "))

# %% [markdown]
# # Aula 6 🔇 🐝 👻

# %%
print("olá, sou seu assistente virtual")
nome = input ("digite seu nome: ")
print(f"olá{nome}, em que posso ajudar?")
resposta = input("Você deseja falar sobre Python, javacript ou matemática: ").lower()
if resposta =="python":
  print(f"Ótimo, {nome},vamos falar sobre Python. \n Python é uma linguagem de programação usada para criar sites, jogos, aplicativos e muito mais, conhecida por ser simples e fácil de aprender. ")
elif resposta == "javascript":
  print(f"ótimo,{nome},vamos falar sobre Javascript. \n JavaScript é uma linguagem de programação usada principalmente para criar interatividade e dinamismo em páginas da web.")
elif resposta == "javascript":
  print(f"Otimo, {nome}, vamos falar sobre matemática. \n Matemática é a ciência que estuda números, formas, medidas e padrões para entender e representar o mundo ao nosso redor.")
else:
    print(f" Que pena, {nome}, não sei falar desse assunto")

# %% [markdown]
# # Aula 7 🦓 🌱 🆗

# %%
import random
dica = [
    "Acredite em você — tudo começa com a sua própria confiança 🌟",
    "Pequenos passos também te levam longe; o importante é não parar 👣",
    "Erros fazem parte do aprendizado — cada falha é uma chance de crescer 📘",
    "Mantenha o foco no que realmente importa e não se distraia com comparações 🎯",
    "Celebre suas conquistas, mesmo as pequenas 🏆",
    "Seja constante, não perfeito 🔁",
    "Cuide da sua mente e do seu corpo — equilíbrio é essencial 🧘‍♂️",
]
while True:
  pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar \n").lower()

  if pedido == "dica":
    dica = random.choice(dica) # escolhe uma dica aleatória sair
    print(f"dica: {dica} \n")
  elif pedido == "sair":
    print("até a próxima! \n")
    break
  else:
    print("omando inválido. tente novmente. \n")
    break
