# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoGHz/Python/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 1 💯 ✅ ⏰

# %%
ano = "IX"
print (ano, " competição de programação dá Start")

# %% [markdown]
# #Aula 2 🥑 🫀 👾

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
